# %% [markdown]
# # Plotting

# %%
#import pandas
import pandas as pd

#read in the glacial data
df = pd.read_csv('glacial_loss.csv')

#see the first 5 rows
df.head()
# Out:
#    year     europe      arctic     alaska       asia  north_america  \
# 0  1961  -5.128903 -108.382987 -18.721190 -32.350759     -14.359007
# 1  1962   5.576282 -173.252450 -24.324790  -4.675440      -2.161842
# 2  1963 -10.123105   -0.423751  -2.047567  -3.027298     -27.535881
# 3  1964  -4.508358   20.070148   0.477800 -18.675385      -2.248286
# 4  1965  10.629385   43.695389  -0.115332 -18.414602     -19.398765
#
#    south_america  antarctica  global_glacial_volume_change  \
# 0      -4.739367  -35.116389                   -220.823515
# 1     -13.694367  -78.222887                   -514.269862
# 2       3.419633    3.765109                   -550.575640
# 3      20.732633   14.853096                   -519.589859
# 4       6.862102   22.793484                   -473.112003
#
#    annual_sea_level_rise  cumulative_sea_level_rise
# 0               0.610010                   0.610010
# 1               0.810625                   1.420635
# ...

# %% [markdown]
# ## Let's start plotting
# `plot()` method
# `pandas.DataFrame` has a built in method `plot()` for plotting.
# Default behavior of the plot function:
# - Creates one line plot for each of the columns with numeric data

# %%
# messy plot
df.plot

# %% [markdown]
# ## Line Plots
# We can make a line plot of one column against another by using the following syntax
# ```
# df.plot(x = 'x_vlaues', y = 'y_values')
# ```
#
# Example

# %%
#Basic Line plot
df.plot(x = 'year', y='europe')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
#Basic Line plot - change in glacial volume per year
df.plot(x = 'year', 
        y='europe',
       xlabel = 'Year',
       ylabel = 'Change in Glacial Volume',
       color = 'red')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Change in Glacial Volume'>

# %% [markdown]
# ## Graph mutlipl line plots on the same graph
# - y : a list of column names that will be plotted against x
# - color: specify the color of each column’s line with a dictionary
# `
# {'col_1' : 'color_1', 'col_2':'color_2}
# `

# %%
#Create the dictionary for the colors:
color_dict = {'arctic':'#F48FB1',
                 'alaska': '#AB47BC'
                 }

#change in glacial volume in the arctic and alaska 
# Two lines on the same graph
df.plot(x = 'year', 
        y=['alaska', 'arctic'],
       xlabel = 'Year',
       ylabel = 'Change in Glacial Volume',
       color = color_dict)
#change in glacial volume in the arctic and alaska 
# Using subplots
df.plot(x = 'year', 
        y=['alaska', 'arctic'],
       xlabel = 'Year',
       ylabel = 'Change in Glacial Volume',
       color = color_dict,
       subplots = True)
# Out:
# array([<AxesSubplot:xlabel='Year', ylabel='Change in Glacial Volume'>,
#        <AxesSubplot:xlabel='Year', ylabel='Change in Glacial Volume'>],
#       dtype=object)

# %% [markdown]
# # Check in 1
# Plot a graph of the annual sea level rise with respect to the years.
# # Check in 2
# What information is the columns variable retrieving from the data frame? Describe in a sentence what is being plotted.
# ```
# columns = df.loc[:,'europe':'antarctica'].columns
# df.plot(x='year',
#         y=columns,
#         subplots=True)
# ```

# %%
#Check in 1
df.plot(x = 'year', 
        y='annual_sea_level_rise',
       xlabel = 'Year',
       ylabel = 'Annual Sea Level Rise',
       color = 'blue')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Annual Sea Level Rise'>

# %%
columns = df.loc[:,'europe':'antarctica'].columns
df.plot(x='year', 
        y=columns, 
        subplots=True)
# Out:
# array([<AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>, <AxesSubplot:xlabel='year'>,
#        <AxesSubplot:xlabel='year'>], dtype=object)

# %%
# df.loc - calls the data based on location
# [:,'europe':'antarctica'] - calls the data for all rows, and for all columns between europe and antacrtica
# '.columns' attribute calls just the column names
df.loc[:,'europe':'antarctica'].columns
# Out:
# Index(['europe', 'arctic', 'alaska', 'asia', 'north_america', 'south_america',
#        'antarctica'],
#       dtype='object')

# %%
# Palmer Penguins Dataset
penguins = pd.read_csv('https://raw.githubusercontent.com/allisonhorst/palmerpenguins/main/inst/extdata/penguins.csv')

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
#Check column data types of the number of NA values in each column
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
# simple statistics about numeric columns
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
# get count unique values in categorical columns and year
penguins[['species', 'island', 'sex', 'year']].nunique()
# Out:
# species    3
# island     3
# sex        2
# year       3
# dtype: int64

# %%
# get unique values in species column
print(penguins.species.unique())
# Out:
# ['Adelie' 'Gentoo' 'Chinstrap']

# %%
# species unique value counts 
print(penguins.species.value_counts())
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %% [markdown]
# # Using the `KIND` Argument
# plot() deafult creates a line plot
#
# parameter that controls the kind of plot that gets made
# **NOTE** the default of the kind argument is line but it can be other things

# %% [markdown]
# ## Scatterplot Examples
# Visually compare the flipper length and body mass

# %%
penguins.plot(kind = 'scatter',
             x = 'flipper_length_mm',
             y = 'body_mass_g',
             xlabel = 'Flipper Length',
             ylabel = 'Body Mass',
             alpha = 0.4)
# Out:
# <AxesSubplot:xlabel='Flpiier Length', ylabel='Body Mass'>

# %% [markdown]
# # Bar Plot
# Lets ay we wan tto get info on the 10 smallest penguins in our dataset.
# 1. Using `nsmallest` and `kind= 'bar'`

# %%
#sort_values puts things in ascending order
smallest = penguins.body_mass_g.nsmallest(10).sort_values(ascending = False)
smallest
# Out:
# 44     3000.0
# 47     2975.0
# 104    2925.0
# 54     2900.0
# 98     2900.0
# 116    2900.0
# 298    2900.0
# 58     2850.0
# 64     2850.0
# 314    2700.0
# Name: body_mass_g, dtype: float64

# %%
smallest.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
penguins.loc[smallest.index]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 44      Adelie      Dream            37.0           16.9              185.0
# 47      Adelie      Dream            37.5           18.9              179.0
# 104     Adelie     Biscoe            37.9           18.6              193.0
# 54      Adelie     Biscoe            34.5           18.1              187.0
# 98      Adelie      Dream            33.1           16.1              178.0
# 116     Adelie  Torgersen            38.6           17.0              188.0
# 298  Chinstrap      Dream            43.2           16.6              187.0
# 58      Adelie     Biscoe            36.5           16.6              181.0
# 64      Adelie     Biscoe            36.4           17.1              184.0
# 314  Chinstrap      Dream            46.9           16.6              192.0
#
#      body_mass_g     sex  year
# 44        3000.0  female  2007
# 47        2975.0     NaN  2007
# 104       2925.0  female  2009
# ...

# %% [markdown]
# ## Histogram
# To create a histogram you only need one variable, set the kind to 'hist' in plot()

# %%
#Using plots without subsetting data - messy
penguins.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Look at flipper length measurements
penguins.flipper_length_mm.plot(kind = 'hist',
                               title = 'Penguin Flipper Length Distrubution',
                                xlabel = 'Flipper Length in mm',
                               color = 'purple',
                               grid = True)
# Out:
# <AxesSubplot:title={'center':'Penguin Flipper Length Distrubution'}, ylabel='Frequency'>

# %% [markdown]
# # Checkin
# - Select the bill_length_mm and bill_depth_mm columns in the penguins dataframe and then update the kind parameter
# to box to make boxplots of the bill length and bill depth.
#
# - Select both rows and columns to create a histogram of the flipper length of gentoo penguins.

# %%
#box_select = penguins[['bill_length_mm','bill_depth_mm']]

#box_select.plot(kind = 'box',
               #subplots = True)

gentoo = penguins.loc[penguins.species == 'Gentoo',['flipper_length_mm']]

gentoo.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Attributes = Static information, not a callable function, no parenthesis
penguins.info
# Out:
# <bound method DataFrame.info of        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
# ...

# %%
#functions = callable, dynamic, uses parethesis, gets called and then goes and retrieves data/info/calculations
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
print(pd. __version__)
# Out:
# 1.3.5
